# %% [markdown]
# 3.2 Эксперимент: Зависимость числа итераций градиентного спуска от числа обусловленности и размерности пространства Исследуйте, как зависит число итераций, необходимое градиентному спуску для сходимости, от сле- дующих двух параметров: 1) числа обусловленности κ≥1 оптимизируемой функции и 2) размерности пространства n оптимизируемых переменных.
#
# Для этого для заданных параметровnиκсгенерируйте случайным образом квадратичную задачу размераnс числом обусловленностиκи запустите на ней градиентный спуск с некоторой фиксиро- ванной требуемой точностью. Замерьте число итераций T(n,κ) , которое потребовалось сделать методу до сходимости (успешному выходу по критерию остановки).
#
# Рекомендация: Проще всего сгенерировать случайную квадратичную задачу размера n с заданным числом обусловленности κ следующим образом. В качестве матрицы A∈Sn++ удобно взять просто диагональную матрицу A=Diag(a) , у которой диагональные элементы сгенерированы случайно в пределах [1,κ] , причем min(a)=1,max(a)=κ . В качестве вектора b∈Rn можно взять вектор со случайными элементами. Диагональные матрицы удобно рассматривать, поскольку с ними можно эффективно работать даже при больших значениях n . Рекомендуется хранить матрицу A в формате разреженной диагональной матрицы (см. scipy.sparse.diags).
#
# Зафиксируйте некоторое значение размерности n . Переберите различные числа обусловленности κ по сетке и постройте график зависимости T(κ,n) против κ . Поскольку каждый раз квадратичная задача генерируется случайным образом, то повторите этот эксперимент несколько раз. В результате для фиксированного значения n у Вас должно получиться целое семейство кривых зависимости T(κ,n) от κ . Нарисуйте все эти кривые одним и тем же цветом для наглядности (например, красным).
#
# Теперь увеличьте значение n и повторите эксперимент снова. Вы должны получить новое семейство кривых T(n',κ) против κ . Нарисуйте их все одним и тем же цветом, но отличным от предыдущего (например, синим).
#
# Повторите эту процедуру несколько раз для других значений n . В итоге должно получиться несколько разных семейств кривых - часть красных (соответствующих одному значению n ), часть синих (соответствующих другому значению n ), часть зеленых и т. д.
#
# Обратите внимание, что значения размерности n имеет смысл перебирать по логарифмической сетке (например, n=10,n=100,n=1000 и т. д.).
#
# Какие выводы можно сделать из полученной картинки?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import diags
from scipy.optimize import line_search

class LineSearchTool(object):
    """
    Line search tool for adaptive step size selection
    """
    def __init__(self, method='Wolfe', **kwargs):
        self.method = method
        self.c1 = kwargs.get('c1', 1e-4)
        self.c2 = kwargs.get('c2', 0.9)
        self.alpha_0 = kwargs.get('alpha_0', 1.0)

    def line_search(self, oracle, x, d):
        """
        Find step size satisfying Wolfe or Armijo conditions
        """
        phi = lambda a: oracle.func_directional(x, d, a)
        phi_grad = lambda a: oracle.grad_directional(x, d, a)

        phi_0 = phi(0)
        phi_grad_0 = phi_grad(0)

        if self.method == 'Constant':
            return self.alpha_0

        elif self.method == 'Wolfe':
            try:
                # Use scipy's line search
                alpha, _, _, _, _, _ = line_search(
                    phi, phi_grad, 0.0, self.alpha_0, c1=self.c1, c2=self.c2
                )
                if alpha is not None:
                    return alpha
            except:
                pass

            # Fallback to backtracking
            return self.backtracking(phi, phi_grad_0, phi_0)

        elif self.method == 'Armijo':
            return self.backtracking(phi, phi_grad_0, phi_0)

        else:
            raise ValueError("Unknown method")

    def backtracking(self, phi, phi_grad_0, phi_0):
        """
        Backtracking line search with Armijo condition
        """
        alpha = self.alpha_0
        c1 = self.c1

        for i in range(50):  # Maximum 50 backtracking steps
            if phi(alpha) <= phi_0 + c1 * alpha * phi_grad_0:
                return alpha
            alpha /= 2.0

        return alpha

def gradient_descent(oracle, x_0, tolerance=1e-5, max_iter=10000, line_search_options=None):
    """
    Gradient descent with line search
    """
    if line_search_options is None:
        line_search_options = {'method': 'Wolfe'}

    line_search_tool = LineSearchTool(**line_search_options)
    x = x_0.copy()
    history = []  # Initialize history

    for k in range(max_iter):
        # Compute gradient and its norm
        grad = oracle.grad(x)
        grad_norm = np.linalg.norm(grad)

        # Store current state in history
        current_func = oracle.func(x)
        history.append((x.copy(), current_func, grad_norm))

        # Check convergence
        if grad_norm < tolerance:
            print(f"Converged in {k} iterations with gradient norm {grad_norm:.2e}")
            return x, 'success', history

        # Descent direction (negative gradient)
        d = -grad

        # Line search for step size
        alpha = line_search_tool.line_search(oracle, x, d)

        # Update position
        x = x + alpha * d

        # Optional: print progress
        if k % 100 == 0:
            print(f"Iteration {k}: f(x) = {current_func:.6f}, ||grad|| = {grad_norm:.2e}")

    print(f"Maximum iterations reached: {max_iter}")
    return x, 'iterations_exceeded', history

class QuadraticOracle:
    """
    Oracle for quadratic function: f(x) = 0.5 * x^T A x - b^T x
    """
    def __init__(self, A, b):
        self.A = A
        self.b = b

    def func(self, x):
        if hasattr(self.A, 'dot'):
            return 0.5 * x.dot(self.A.dot(x)) - self.b.dot(x)
        else:
            return 0.5 * x.T @ self.A @ x - self.b.T @ x

    def grad(self, x):
        if hasattr(self.A, 'dot'):
            return self.A.dot(x) - self.b
        else:
            return self.A @ x - self.b

    def hess(self, x):
        return self.A

    def func_directional(self, x, d, alpha):
        return self.func(x + alpha * d)

    def grad_directional(self, x, d, alpha):
        grad_val = self.grad(x + alpha * d)
        return grad_val.dot(d)

def generate_quadratic_problem(n, kappa, random_state=None):
    """
    Generate quadratic problem with condition number kappa and dimension n
    """
    if random_state is not None:
        np.random.seed(random_state)

    # Generate diagonal elements with exact condition number kappa
    diag_vals = np.ones(n)
    if n > 1:
        # Create eigenvalues that span from 1 to kappa
        diag_vals = np.linspace(1, kappa, n)
        # Shuffle to avoid sorted order
        np.random.shuffle(diag_vals)

    # Create diagonal matrix (sparse format for efficiency)
    A = diags(diag_vals, format='csr')

    # Generate random vector b
    b = np.random.randn(n)

    # Generate random initial point
    x_0 = np.random.randn(n)

    oracle = QuadraticOracle(A, b)
    return oracle, x_0

def run_experiment(n_values, kappa_values, num_trials=5, tolerance=1e-5, max_iter=10000):
    """
    Run experiment for different dimensions and condition numbers
    """
    results = {}

    for n in n_values:
        print(f"Running experiments for n={n}...")
        results[n] = {}

        for kappa in kappa_values:
            results[n][kappa] = []

            for trial in range(num_trials):
                # Generate random problem
                oracle, x_0 = generate_quadratic_problem(n, kappa,
                                                       random_state=trial + n * 1000)

                try:
                    # Run gradient descent
                    x_opt, status, history = gradient_descent(
                        oracle, x_0, tolerance=tolerance, max_iter=max_iter,
                        line_search_options={'method': 'Wolfe'}
                    )

                    # Record number of iterations
                    if history is not None:
                        iterations = len(history)
                        results[n][kappa].append(iterations)
                        print(f"  n={n}, κ={kappa}, trial={trial}: {iterations} iterations")
                    else:
                        print(f"Warning: No history for n={n}, kappa={kappa}, trial={trial}")
                        results[n][kappa].append(max_iter)

                except Exception as e:
                    print(f"Error for n={n}, kappa={kappa}, trial={trial}: {e}")
                    results[n][kappa].append(max_iter)

    return results

def plot_results(results, kappa_values, n_values):
    """
    Plot the results of the experiment
    """
    plt.figure(figsize=(12, 8))

    # Color map for different n values
    colors = ['red', 'blue', 'green', 'orange', 'purple', 'brown', 'pink', 'gray']
    markers = ['o', 's', '^', 'D', 'v', '<', '>', 'p']

    for i, n in enumerate(n_values):
        if n not in results:
            continue

        color = colors[i % len(colors)]
        marker = markers[i % len(markers)]

        # Extract iteration counts for this n
        kappas_plot = []
        mean_iterations = []
        std_iterations = []

        for kappa in kappa_values:
            if kappa in results[n] and len(results[n][kappa]) > 0:
                kappas_plot.append(kappa)
                mean_iterations.append(np.mean(results[n][kappa]))
                std_iterations.append(np.std(results[n][kappa]))

        if len(kappas_plot) > 0:
            # Plot mean with error bars
            plt.errorbar(kappas_plot, mean_iterations, yerr=std_iterations,
                        color=color, marker=marker, markersize=8,
                        linewidth=2, capsize=5, label=f'n={n}')

            # Plot individual trials as faint points
            for kappa in kappa_values:
                if kappa in results[n]:
                    for trial_iter in results[n][kappa]:
                        plt.scatter(kappa, trial_iter, color=color, alpha=0.3)

    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('Condition Number κ (log scale)')
    plt.ylabel('Number of Iterations T(κ,n) (log scale)')
    plt.title('Dependence of Gradient Descent Iterations on Condition Number and Dimension')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

def analyze_convergence_rate(results, kappa_values, n_values):
    """
    Analyze the theoretical vs empirical convergence rates
    """
    print("\n=== Convergence Rate Analysis ===")

    for n in n_values:
        if n not in results:
            continue

        print(f"\nFor n={n}:")

        # Collect data for linear regression
        log_kappas = []
        log_iters = []

        for kappa in kappa_values:
            if kappa in results[n] and len(results[n][kappa]) > 0:
                log_kappas.append(np.log(kappa))
                log_iters.append(np.log(np.mean(results[n][kappa])))

        if len(log_kappas) > 1:
            # Linear regression in log-log space
            slope, intercept = np.polyfit(log_kappas, log_iters, 1)
            correlation = np.corrcoef(log_kappas, log_iters)[0,1]
            print(f"  Empirical exponent: {slope:.3f}")
            print(f"  R² score: {correlation**2:.3f}")

# Test with a simple case first
def test_gradient_descent():
    """Test gradient descent on a simple problem"""
    print("Testing gradient descent on simple problem...")

    # Simple 2D quadratic
    A = diags([1, 10], format='csr')  # Condition number 10
    b = np.array([1, 2])
    oracle = QuadraticOracle(A, b)
    x_0 = np.array([0, 0])

    try:
        x_opt, status, history = gradient_descent(
            oracle, x_0, tolerance=1e-5, max_iter=1000,
            line_search_options={'method': 'Wolfe'}
        )

        if history is not None:
            print(f"Success! Iterations: {len(history)}, Status: {status}")
            print(f"Final gradient norm: {np.linalg.norm(oracle.grad(x_opt)):.6f}")
            return True
        else:
            print("No history returned")
            return False

    except Exception as e:
        print(f"Error in test: {e}")
        return False

# Main experiment
if __name__ == "__main__":
    # First test if gradient descent works
    if not test_gradient_descent():
        print("Gradient descent test failed. Check the implementation.")
        exit()

    # Parameters for the experiment
    n_values = [10, 50, 100]  # Dimensions to test
    kappa_values = [1, 2, 5, 10, 20, 50, 100, 200]  # Condition numbers to test
    num_trials = 3  # Number of random trials
    tolerance = 1e-6
    max_iter = 10000

    print("\n" + "="*60)
    print("Starting gradient descent condition number experiment...")
    print(f"Testing dimensions: {n_values}")
    print(f"Testing condition numbers: {kappa_values}")
    print(f"Trials per configuration: {num_trials}")
    print(f"Tolerance: {tolerance}")
    print("="*60)

    # Run the experiment
    results = run_experiment(n_values, kappa_values, num_trials, tolerance, max_iter)

    # Plot results
    plot_results(results, kappa_values, n_values)

    # Analyze convergence rates
    analyze_convergence_rate(results, kappa_values, n_values)

    # Show summary statistics
    print("\n=== Summary Statistics ===")
    for n in n_values:
        if n in results:
            print(f"\nn={n}:")
            for kappa in kappa_values:
                if kappa in results[n] and len(results[n][kappa]) > 0:
                    iters = results[n][kappa]
                    print(f"  κ={kappa:4d}: mean={np.mean(iters):6.1f}, "
                          f"std={np.std(iters):5.1f}, range=[{min(iters):3d}, {max(iters):3d}]")
# Out:
# Testing gradient descent on simple problem...
# Iteration 0: f(x) = 0.000000, ||grad|| = 2.24e+00
# Converged in 43 iterations with gradient norm 5.97e-06
# Success! Iterations: 44, Status: success
# Final gradient norm: 0.000006
#
# ============================================================
# Starting gradient descent condition number experiment...
# Testing dimensions: [10, 50, 100]
# Testing condition numbers: [1, 2, 5, 10, 20, 50, 100, 200]
# Trials per configuration: 3
# Tolerance: 1e-06
# ============================================================
# Running experiments for n=10...
# Iteration 0: f(x) = 5.314057, ||grad|| = 3.84e+00
# Converged in 1 iterations with gradient norm 2.05e-16
#   n=10, κ=1, trial=0: 2 iterations
# Iteration 0: f(x) = 12.790702, ||grad|| = 5.90e+00
# Converged in 1 iterations with gradient norm 2.94e-16
#   n=10, κ=1, trial=1: 2 iterations
# Iteration 0: f(x) = 3.960499, ||grad|| = 5.23e+00
# Converged in 1 iterations with gradient norm 3.00e-16
#   n=10, κ=1, trial=2: 2 iterations
# Iteration 0: f(x) = 7.731994, ||grad|| = 5.37e+00
# Converged in 23 iterations with gradient norm 8.49e-08
#   n=10, κ=2, trial=0: 24 iterations
# Iteration 0: f(x) = 16.215550, ||grad|| = 7.80e+00
# Converged in 19 iterations with gradient norm 3.52e-07
#   n=10, κ=2, trial=1: 20 iterations
# Iteration 0: f(x) = 6.771804, ||grad|| = 6.69e+00
# Converged in 20 iterations with gradient norm 5.11e-07
#   n=10, κ=2, trial=2: 21 iterations
# Iteration 0: f(x) = 14.985807, ||grad|| = 1.03e+01
# Converged in 35 iterations with gradient norm 8.55e-07
#   n=10, κ=5, trial=0: 36 iterations
# Iteration 0: f(x) = 26.490095, ||grad|| = 1.39e+01
# Converged in 37 iterations with gradient norm 8.56e-07
#   n=10, κ=5, trial=1: 38 iterations
# Iteration 0: f(x) = 15.205720, ||grad|| = 1.23e+01
# Converged in 36 iterations with gradient norm 8.97e-07
#   n=10, κ=5, trial=2: 37 iterations
# Iteration 0: f(x) = 27.075495, ||grad|| = 1.87e+01
# Converged in 70 iterations with gradient norm 9.96e-07
#   n=10, κ=10, trial=0: 71 iterations
# Iteration 0: f(x) = 43.614335, ||grad|| = 2.44e+01
# Converged in 74 iterations with gradient norm 9.49e-07
#   n=10, κ=10, trial=1: 75 iterations
# Iteration 0: f(x) = 29.262246, ||grad|| = 2.26e+01
# Converged in 73 iterations with gradient norm 9.29e-07
#   n=10, κ=10, trial=2: 74 iterations
# Iteration 0: f(x) = 51.254872, ||grad|| = 3.56e+01
# Iteration 100: f(x) = -0.588386, ||grad|| = 3.16e-05
# Converged in 135 iterations with gradient norm 9.97e-07
#   n=10, κ=20, trial=0: 136 iterations
# Iteration 0: f(x) = 77.862816, ||grad|| = 4.56e+01
# Iteration 100: f(x) = -0.650986, ||grad|| = 2.78e-05
# Converged in 130 iterations with gradient norm 9.78e-07
#   n=10, κ=20, trial=1: 131 iterations
# Iteration 0: f(x) = 57.375299, ||grad|| = 4.37e+01
# Iteration 100: f(x) = -2.078028, ||grad|| = 4.67e-05
# Converged in 133 iterations with gradient norm 9.59e-07
#   n=10, κ=20, trial=2: 134 iterations
# Iteration 0: f(x) = 123.793001, ||grad|| = 8.65e+01
# Iteration 100: f(x) = -0.346257, ||grad|| = 1.45e-02
# Iteration 200: f(x) = -0.346325, ||grad|| = 1.86e-04
# Iteration 300: f(x) = -0.346325, ||grad|| = 2.40e-06
# Converged in 322 iterations with gradient norm 9.21e-07
#   n=10, κ=50, trial=0: 323 iterations
# Iteration 0: f(x) = 180.608259, ||grad|| = 1.09e+02
# Iteration 100: f(x) = -0.369635, ||grad|| = 5.93e-04
# Converged in 164 iterations with gradient norm 9.90e-07
#   n=10, κ=50, trial=1: 165 iterations
# Iteration 0: f(x) = 141.714457, ||grad|| = 1.07e+02
# Iteration 100: f(x) = -1.382943, ||grad|| = 9.35e-03
# Iteration 200: f(x) = -1.382976, ||grad|| = 4.15e-05
# Converged in 270 iterations with gradient norm 9.36e-07
#   n=10, κ=50, trial=2: 271 iterations
# Iteration 0: f(x) = 244.689883, ||grad|| = 1.71e+02
# Iteration 100: f(x) = -0.245070, ||grad|| = 8.16e-03
# Iteration 200: f(x) = -0.245091, ||grad|| = 9.43e-04
# Iteration 300: f(x) = -0.245091, ||grad|| = 1.09e-04
# Iteration 400: f(x) = -0.245091, ||grad|| = 1.26e-05
# Iteration 500: f(x) = -0.245091, ||grad|| = 1.45e-06
# Converged in 518 iterations with gradient norm 9.86e-07
#   n=10, κ=100, trial=0: 519 iterations
# Iteration 0: f(x) = 351.850664, ||grad|| = 2.16e+02
# Converged in 59 iterations with gradient norm 6.98e-10
#   n=10, κ=100, trial=1: 60 iterations
# Iteration 0: f(x) = 282.279721, ||grad|| = 2.14e+02
# Iteration 100: f(x) = -1.107080, ||grad|| = 4.90e-02
# Iteration 200: f(x) = -1.108004, ||grad|| = 3.00e-03
# Iteration 300: f(x) = -1.108008, ||grad|| = 1.84e-04
# Iteration 400: f(x) = -1.108008, ||grad|| = 1.12e-05
# Converged in 488 iterations with gradient norm 9.62e-07
#   n=10, κ=100, trial=2: 489 iterations
# Iteration 0: f(x) = 486.483647, ||grad|| = 3.41e+02
# Iteration 100: f(x) = -0.161840, ||grad|| = 3.77e-01
# Iteration 200: f(x) = -0.185970, ||grad|| = 1.30e-01
# Iteration 300: f(x) = -0.188907, ||grad|| = 4.49e-02
# Iteration 400: f(x) = -0.189271, ||grad|| = 1.60e-02
# Iteration 500: f(x) = -0.189317, ||grad|| = 5.69e-03
# Iteration 600: f(x) = -0.189323, ||grad|| = 2.03e-03
# Iteration 700: f(x) = -0.189324, ||grad|| = 7.22e-04
# Iteration 800: f(x) = -0.189324, ||grad|| = 2.57e-04
# Iteration 900: f(x) = -0.189324, ||grad|| = 9.16e-05
# Iteration 1000: f(x) = -0.189324, ||grad|| = 3.26e-05
# Iteration 1100: f(x) = -0.189324, ||grad|| = 1.16e-05
# Iteration 1200: f(x) = -0.189324, ||grad|| = 4.14e-06
# Iteration 1300: f(x) = -0.189324, ||grad|| = 1.47e-06
# Converged in 1321 iterations with gradient norm 9.93e-07
#   n=10, κ=200, trial=0: 1322 iterations
# Iteration 0: f(x) = 694.335475, ||grad|| = 4.29e+02
# Iteration 100: f(x) = -0.163848, ||grad|| = 3.17e-01
# Iteration 200: f(x) = -0.204403, ||grad|| = 1.60e-01
# Iteration 300: f(x) = -0.207514, ||grad|| = 4.37e-02
# Iteration 400: f(x) = -0.207746, ||grad|| = 1.19e-02
# Iteration 500: f(x) = -0.207763, ||grad|| = 3.25e-03
# Iteration 600: f(x) = -0.207765, ||grad|| = 8.87e-04
# Iteration 700: f(x) = -0.207765, ||grad|| = 2.42e-04
# Iteration 800: f(x) = -0.207765, ||grad|| = 6.60e-05
# Iteration 900: f(x) = -0.207765, ||grad|| = 1.80e-05
# Iteration 1000: f(x) = -0.207765, ||grad|| = 4.92e-06
# Converged in 1083 iterations with gradient norm 9.96e-07
#   n=10, κ=200, trial=1: 1084 iterations
# Iteration 0: f(x) = 563.410249, ||grad|| = 4.26e+02
# Iteration 100: f(x) = -0.924982, ||grad|| = 3.19e-01
# Iteration 200: f(x) = -0.956116, ||grad|| = 1.04e-01
# Iteration 300: f(x) = -0.959335, ||grad|| = 3.36e-02
# Iteration 400: f(x) = -0.959673, ||grad|| = 1.09e-02
# /tmp/ipython-input-1942401446.py:32: LineSearchWarning: The line search algorithm did not converge
#   alpha, _, _, _, _, _ = line_search(
# Iteration 500: f(x) = -0.959708, ||grad|| = 3.53e-03
# Iteration 600: f(x) = -0.959712, ||grad|| = 1.15e-03
# Iteration 700: f(x) = -0.959713, ||grad|| = 3.71e-04
# Iteration 800: f(x) = -0.959713, ||grad|| = 1.20e-04
# Iteration 900: f(x) = -0.959713, ||grad|| = 3.90e-05
# Iteration 1000: f(x) = -0.959713, ||grad|| = 1.27e-05
# Iteration 1100: f(x) = -0.959713, ||grad|| = 4.11e-06
# Iteration 1200: f(x) = -0.959713, ||grad|| = 1.34e-06
# Converged in 1228 iterations with gradient norm 9.83e-07
#   n=10, κ=200, trial=2: 1229 iterations
# Running experiments for n=50...
# Iteration 0: f(x) = 18.623913, ||grad|| = 9.19e+00
# Converged in 1 iterations with gradient norm 3.73e-16
#   n=50, κ=1, trial=0: 2 iterations
# Iteration 0: f(x) = 26.387937, ||grad|| = 1.09e+01
# Converged in 1 iterations with gradient norm 6.77e-16
#   n=50, κ=1, trial=1: 2 iterations
# Iteration 0: f(x) = 13.105909, ||grad|| = 8.35e+00
# Converged in 1 iterations with gradient norm 3.17e-16
#   n=50, κ=1, trial=2: 2 iterations
# Iteration 0: f(x) = 31.070529, ||grad|| = 1.21e+01
# Converged in 21 iterations with gradient norm 3.41e-07
#   n=50, κ=2, trial=0: 22 iterations
# Iteration 0: f(x) = 41.428532, ||grad|| = 1.42e+01
# Converged in 20 iterations with gradient norm 8.54e-07
#   n=50, κ=2, trial=1: 21 iterations
# Iteration 0: f(x) = 26.479977, ||grad|| = 1.19e+01
# Converged in 21 iterations with gradient norm 2.43e-07
#   n=50, κ=2, trial=2: 22 iterations
# Iteration 0: f(x) = 68.410379, ||grad|| = 2.30e+01
# Converged in 36 iterations with gradient norm 6.93e-07
#   n=50, κ=5, trial=0: 37 iterations
# Iteration 0: f(x) = 86.550319, ||grad|| = 2.67e+01
# Converged in 37 iterations with gradient norm 6.00e-07
#   n=50, κ=5, trial=1: 38 iterations
# Iteration 0: f(x) = 66.602181, ||grad|| = 2.47e+01
# Converged in 31 iterations with gradient norm 9.36e-07
#   n=50, κ=5, trial=2: 32 iterations
# Iteration 0: f(x) = 130.643462, ||grad|| = 4.27e+01
# Converged in 71 iterations with gradient norm 8.11e-07
#   n=50, κ=10, trial=0: 72 iterations
# Iteration 0: f(x) = 161.753296, ||grad|| = 4.95e+01
# Converged in 73 iterations with gradient norm 7.40e-07
#   n=50, κ=10, trial=1: 74 iterations
# Iteration 0: f(x) = 133.472521, ||grad|| = 4.72e+01
# Converged in 63 iterations with gradient norm 9.24e-07
#   n=50, κ=10, trial=2: 64 iterations
# Iteration 0: f(x) = 255.109628, ||grad|| = 8.30e+01
# Iteration 100: f(x) = -3.635185, ||grad|| = 3.56e-06
# Converged in 107 iterations with gradient norm 8.84e-07
#   n=50, κ=20, trial=0: 108 iterations
# Iteration 0: f(x) = 312.159251, ||grad|| = 9.61e+01
# Iteration 100: f(x) = -6.761890, ||grad|| = 9.11e-05
# Converged in 145 iterations with gradient norm 8.60e-07
#   n=50, κ=20, trial=1: 146 iterations
# Iteration 0: f(x) = 267.213201, ||grad|| = 9.29e+01
# Converged in 100 iterations with gradient norm 7.76e-07
#   n=50, κ=20, trial=2: 101 iterations
# Iteration 0: f(x) = 628.508126, ||grad|| = 2.04e+02
# Iteration 100: f(x) = -1.889082, ||grad|| = 9.38e-03
# Iteration 200: f(x) = -1.889093, ||grad|| = 4.60e-05
# Converged in 263 iterations with gradient norm 9.47e-07
#   n=50, κ=50, trial=0: 264 iterations
# Iteration 0: f(x) = 763.377116, ||grad|| = 2.37e+02
# Iteration 100: f(x) = -3.879192, ||grad|| = 1.83e-02
# Iteration 200: f(x) = -3.879234, ||grad|| = 7.80e-05
# Converged in 271 iterations with gradient norm 9.25e-07
#   n=50, κ=50, trial=1: 272 iterations
# Iteration 0: f(x) = 668.435241, ||grad|| = 2.31e+02
# Iteration 100: f(x) = -2.505794, ||grad|| = 2.00e-03
# Iteration 200: f(x) = -2.505796, ||grad|| = 1.37e-05
# Converged in 254 iterations with gradient norm 9.22e-07
#   n=50, κ=50, trial=2: 255 iterations
# Iteration 0: f(x) = 1250.838956, ||grad|| = 4.07e+02
# Iteration 100: f(x) = -1.184078, ||grad|| = 8.16e-02
# Iteration 200: f(x) = -1.186478, ||grad|| = 6.78e-03
# Iteration 300: f(x) = -1.186495, ||grad|| = 5.64e-04
# Iteration 400: f(x) = -1.186495, ||grad|| = 4.69e-05
# Iteration 500: f(x) = -1.186495, ||grad|| = 3.90e-06
# Converged in 556 iterations with gradient norm 9.65e-07
#   n=50, κ=100, trial=0: 557 iterations
# Iteration 0: f(x) = 1515.406891, ||grad|| = 4.72e+02
# Iteration 100: f(x) = -2.613773, ||grad|| = 6.04e-02
# Iteration 200: f(x) = -2.614978, ||grad|| = 6.41e-03
# Iteration 300: f(x) = -2.614992, ||grad|| = 6.81e-04
# Iteration 400: f(x) = -2.614992, ||grad|| = 7.23e-05
# Iteration 500: f(x) = -2.614992, ||grad|| = 7.68e-06
# Converged in 592 iterations with gradient norm 9.80e-07
#   n=50, κ=100, trial=1: 593 iterations
# Iteration 0: f(x) = 1337.138641, ||grad|| = 4.60e+02
# Iteration 100: f(x) = -1.670875, ||grad|| = 4.29e-02
# Iteration 200: f(x) = -1.671315, ||grad|| = 5.66e-03
# Iteration 300: f(x) = -1.671323, ||grad|| = 7.66e-04
# Iteration 400: f(x) = -1.671323, ||grad|| = 1.04e-04
# Iteration 500: f(x) = -1.671323, ||grad|| = 1.40e-05
# Iteration 600: f(x) = -1.671323, ||grad|| = 1.89e-06
# Converged in 632 iterations with gradient norm 9.96e-07
#   n=50, κ=100, trial=2: 633 iterations
# Iteration 0: f(x) = 2495.500616, ||grad|| = 8.13e+02
# Iteration 100: f(x) = -0.766772, ||grad|| = 4.55e-01
# Iteration 200: f(x) = -0.795041, ||grad|| = 1.38e-01
# Iteration 300: f(x) = -0.797642, ||grad|| = 4.18e-02
# Iteration 400: f(x) = -0.797881, ||grad|| = 1.27e-02
# Iteration 500: f(x) = -0.797903, ||grad|| = 3.85e-03
# Iteration 600: f(x) = -0.797905, ||grad|| = 1.17e-03
# Iteration 700: f(x) = -0.797905, ||grad|| = 3.55e-04
# Iteration 800: f(x) = -0.797905, ||grad|| = 1.08e-04
# Iteration 900: f(x) = -0.797905, ||grad|| = 3.27e-05
# Iteration 1000: f(x) = -0.797905, ||grad|| = 9.93e-06
# Iteration 1100: f(x) = -0.797905, ||grad|| = 3.01e-06
# Converged in 1157 iterations with gradient norm 9.98e-07
#   n=50, κ=200, trial=0: 1158 iterations
# Iteration 0: f(x) = 3019.466441, ||grad|| = 9.42e+02
# Iteration 100: f(x) = -1.754855, ||grad|| = 5.87e-01
# Iteration 200: f(x) = -1.866140, ||grad|| = 1.50e-01
# Iteration 300: f(x) = -1.873978, ||grad|| = 3.96e-02
# Iteration 400: f(x) = -1.874525, ||grad|| = 1.05e-02
# Iteration 500: f(x) = -1.874564, ||grad|| = 2.76e-03
# Iteration 600: f(x) = -1.874566, ||grad|| = 7.30e-04
# Iteration 700: f(x) = -1.874567, ||grad|| = 1.93e-04
# Iteration 800: f(x) = -1.874567, ||grad|| = 5.10e-05
# Iteration 900: f(x) = -1.874567, ||grad|| = 1.35e-05
# Iteration 1000: f(x) = -1.874567, ||grad|| = 3.56e-06
# Converged in 1096 iterations with gradient norm 9.87e-07
#   n=50, κ=200, trial=1: 1097 iterations
# Iteration 0: f(x) = 2674.545440, ||grad|| = 9.19e+02
# Iteration 100: f(x) = -1.167495, ||grad|| = 1.26e-01
# Iteration 200: f(x) = -1.169684, ||grad|| = 3.87e-02
# Iteration 300: f(x) = -1.169902, ||grad|| = 1.23e-02
# Iteration 400: f(x) = -1.169924, ||grad|| = 3.91e-03
# Iteration 500: f(x) = -1.169926, ||grad|| = 1.24e-03
# Iteration 600: f(x) = -1.169926, ||grad|| = 3.95e-04
# Iteration 700: f(x) = -1.169926, ||grad|| = 1.26e-04
# Iteration 800: f(x) = -1.169926, ||grad|| = 3.99e-05
# Iteration 900: f(x) = -1.169926, ||grad|| = 1.27e-05
# Iteration 1000: f(x) = -1.169926, ||grad|| = 4.04e-06
# Converged in 1089 iterations with gradient norm 9.88e-07
#   n=50, κ=200, trial=2: 1090 iterations
# Running experiments for n=100...
# Iteration 0: f(x) = 57.383960, ||grad|| = 1.45e+01
# Converged in 1 iterations with gradient norm 7.81e-16
#   n=100, κ=1, trial=0: 2 iterations
# Iteration 0: f(x) = 56.586871, ||grad|| = 1.45e+01
# Converged in 1 iterations with gradient norm 5.96e-16
#   n=100, κ=1, trial=1: 2 iterations
# Iteration 0: f(x) = 52.289055, ||grad|| = 1.41e+01
# Converged in 1 iterations with gradient norm 8.12e-16
#   n=100, κ=1, trial=2: 2 iterations
# Iteration 0: f(x) = 87.889773, ||grad|| = 1.96e+01
# Converged in 20 iterations with gradient norm 9.32e-07
#   n=100, κ=2, trial=0: 21 iterations
# Iteration 0: f(x) = 87.320415, ||grad|| = 1.95e+01
# Converged in 20 iterations with gradient norm 8.64e-07
#   n=100, κ=2, trial=1: 21 iterations
# Iteration 0: f(x) = 76.197583, ||grad|| = 1.82e+01
# Converged in 20 iterations with gradient norm 7.81e-07
#   n=100, κ=2, trial=2: 21 iterations
# Iteration 0: f(x) = 179.407211, ||grad|| = 3.72e+01
# Converged in 35 iterations with gradient norm 9.60e-07
#   n=100, κ=5, trial=0: 36 iterations
# Iteration 0: f(x) = 179.521047, ||grad|| = 3.74e+01
# Converged in 37 iterations with gradient norm 6.68e-07
#   n=100, κ=5, trial=1: 38 iterations
# Iteration 0: f(x) = 147.923166, ||grad|| = 3.32e+01
# Converged in 39 iterations with gradient norm 6.66e-07
#   n=100, κ=5, trial=2: 40 iterations
# Iteration 0: f(x) = 331.936274, ||grad|| = 6.83e+01
# Converged in 69 iterations with gradient norm 8.41e-07
#   n=100, κ=10, trial=0: 70 iterations
# Iteration 0: f(x) = 333.188767, ||grad|| = 6.93e+01
# Converged in 73 iterations with gradient norm 8.26e-07
#   n=100, κ=10, trial=1: 74 iterations
# Iteration 0: f(x) = 267.465805, ||grad|| = 6.06e+01
# Converged in 78 iterations with gradient norm 8.72e-07
#   n=100, κ=10, trial=2: 79 iterations
# Iteration 0: f(x) = 636.994399, ||grad|| = 1.32e+02
# Iteration 100: f(x) = -8.530152, ||grad|| = 3.08e-06
# Converged in 107 iterations with gradient norm 7.85e-07
#   n=100, κ=20, trial=0: 108 iterations
# Iteration 0: f(x) = 640.524206, ||grad|| = 1.34e+02
# Iteration 100: f(x) = -8.349170, ||grad|| = 1.20e-05
# Converged in 117 iterations with gradient norm 8.52e-07
#   n=100, κ=20, trial=1: 118 iterations
# Iteration 0: f(x) = 506.551082, ||grad|| = 1.17e+02
# Converged in 81 iterations with gradient norm 7.25e-07
#   n=100, κ=20, trial=2: 82 iterations
# Iteration 0: f(x) = 1552.168777, ||grad|| = 3.22e+02
# Iteration 100: f(x) = -4.241432, ||grad|| = 5.51e-03
# Iteration 200: f(x) = -4.241442, ||grad|| = 6.43e-05
# Converged in 296 iterations with gradient norm 9.20e-07
#   n=100, κ=50, trial=0: 297 iterations
# Iteration 0: f(x) = 1562.530525, ||grad|| = 3.30e+02
# Iteration 100: f(x) = -5.182426, ||grad|| = 2.03e-03
# Iteration 200: f(x) = -5.182428, ||grad|| = 1.76e-06
# Converged in 208 iterations with gradient norm 9.97e-07
#   n=100, κ=50, trial=1: 209 iterations
# Iteration 0: f(x) = 1223.806912, ||grad|| = 2.86e+02
# Iteration 100: f(x) = -5.161361, ||grad|| = 3.07e-02
# Iteration 200: f(x) = -5.161716, ||grad|| = 1.60e-04
# Converged in 298 iterations with gradient norm 9.28e-07
#   n=100, κ=50, trial=2: 299 iterations
# Iteration 0: f(x) = 3077.459405, ||grad|| = 6.40e+02
# Iteration 100: f(x) = -2.396508, ||grad|| = 6.03e-02
# Iteration 200: f(x) = -2.397645, ||grad|| = 6.24e-03
# Iteration 300: f(x) = -2.397658, ||grad|| = 6.76e-04
# Iteration 400: f(x) = -2.397658, ||grad|| = 7.33e-05
# Iteration 500: f(x) = -2.397658, ||grad|| = 7.94e-06
# Converged in 594 iterations with gradient norm 9.82e-07
#   n=100, κ=100, trial=0: 595 iterations
# Iteration 0: f(x) = 3099.207723, ||grad|| = 6.56e+02
# Iteration 100: f(x) = -3.898429, ||grad|| = 9.95e-02
# Iteration 200: f(x) = -3.900205, ||grad|| = 1.13e-02
# Iteration 300: f(x) = -3.900228, ||grad|| = 1.29e-03
# Iteration 400: f(x) = -3.900229, ||grad|| = 1.46e-04
# Iteration 500: f(x) = -3.900229, ||grad|| = 1.66e-05
# Iteration 600: f(x) = -3.900229, ||grad|| = 1.89e-06
# Converged in 617 iterations with gradient norm 9.85e-07
#   n=100, κ=100, trial=1: 618 iterations
# Iteration 0: f(x) = 2419.233297, ||grad|| = 5.69e+02
# Iteration 100: f(x) = -3.751587, ||grad|| = 1.19e-02
# Iteration 200: f(x) = -3.751602, ||grad|| = 6.60e-04
# Iteration 300: f(x) = -3.751602, ||grad|| = 3.74e-05
# Iteration 400: f(x) = -3.751602, ||grad|| = 2.12e-06
# Converged in 405 iterations with gradient norm 9.91e-07
#   n=100, κ=100, trial=2: 406 iterations
# Iteration 0: f(x) = 6128.040663, ||grad|| = 1.28e+03
# Iteration 100: f(x) = -1.301951, ||grad|| = 2.28e-01
# Iteration 200: f(x) = -1.309971, ||grad|| = 7.42e-02
# Iteration 300: f(x) = -1.310870, ||grad|| = 2.53e-02
# Iteration 400: f(x) = -1.310974, ||grad|| = 8.62e-03
# Iteration 500: f(x) = -1.310987, ||grad|| = 2.94e-03
# Iteration 600: f(x) = -1.310988, ||grad|| = 1.00e-03
# Iteration 700: f(x) = -1.310988, ||grad|| = 3.42e-04
# Iteration 800: f(x) = -1.310988, ||grad|| = 1.17e-04
# Iteration 900: f(x) = -1.310988, ||grad|| = 3.98e-05
# Iteration 1000: f(x) = -1.310988, ||grad|| = 1.36e-05
# Iteration 1100: f(x) = -1.310988, ||grad|| = 4.63e-06
# Iteration 1200: f(x) = -1.310988, ||grad|| = 1.57e-06
# Converged in 1219 iterations with gradient norm 9.95e-07
#   n=100, κ=200, trial=0: 1220 iterations
# Iteration 0: f(x) = 6172.562118, ||grad|| = 1.31e+03
# Iteration 100: f(x) = -3.068975, ||grad|| = 5.52e-01
# Iteration 200: f(x) = -3.161045, ||grad|| = 1.75e-01
# Iteration 300: f(x) = -3.170416, ||grad|| = 5.61e-02
# Iteration 400: f(x) = -3.171374, ||grad|| = 1.79e-02
# Iteration 500: f(x) = -3.171471, ||grad|| = 5.73e-03
# Iteration 600: f(x) = -3.171481, ||grad|| = 1.83e-03
# Iteration 700: f(x) = -3.171482, ||grad|| = 5.86e-04
# Iteration 800: f(x) = -3.171483, ||grad|| = 1.87e-04
# Iteration 900: f(x) = -3.171483, ||grad|| = 5.99e-05
# Iteration 1000: f(x) = -3.171483, ||grad|| = 1.92e-05
# Iteration 1100: f(x) = -3.171483, ||grad|| = 6.12e-06
# Iteration 1200: f(x) = -3.171483, ||grad|| = 1.95e-06
# Converged in 1258 iterations with gradient norm 9.77e-07
#   n=100, κ=200, trial=1: 1259 iterations
# Iteration 0: f(x) = 4810.086067, ||grad|| = 1.13e+03
# Iteration 100: f(x) = -2.655998, ||grad|| = 9.14e-01
# Iteration 200: f(x) = -2.975566, ||grad|| = 1.62e-02
# Iteration 300: f(x) = -2.975630, ||grad|| = 5.87e-03
# Iteration 400: f(x) = -2.975638, ||grad|| = 2.13e-03
# Iteration 500: f(x) = -2.975639, ||grad|| = 7.74e-04
# Iteration 600: f(x) = -2.975640, ||grad|| = 2.81e-04
# Iteration 700: f(x) = -2.975640, ||grad|| = 1.02e-04
# Iteration 800: f(x) = -2.975640, ||grad|| = 3.70e-05
# Iteration 900: f(x) = -2.975640, ||grad|| = 1.34e-05
# Iteration 1000: f(x) = -2.975640, ||grad|| = 4.88e-06
# Iteration 1100: f(x) = -2.975640, ||grad|| = 1.75e-06
# Converged in 1152 iterations with gradient norm 9.91e-07
#   n=100, κ=200, trial=2: 1153 iterations
# === Convergence Rate Analysis ===
#
# For n=10:
#   Empirical exponent: 1.013
#   R² score: 0.930
#
# For n=50:
#   Empirical exponent: 1.047
#   R² score: 0.945
#
# For n=100:
#   Empirical exponent: 1.046
#   R² score: 0.944
#
# === Summary Statistics ===
#
# n=10:
#   κ=   1: mean=   2.0, std=  0.0, range=[  2,   2]
#   κ=   2: mean=  21.7, std=  1.7, range=[ 20,  24]
#   κ=   5: mean=  37.0, std=  0.8, range=[ 36,  38]
#   κ=  10: mean=  73.3, std=  1.7, range=[ 71,  75]
#   κ=  20: mean= 133.7, std=  2.1, range=[131, 136]
#   κ=  50: mean= 253.0, std= 65.7, range=[165, 323]
#   κ= 100: mean= 356.0, std=209.7, range=[ 60, 519]
#   κ= 200: mean=1211.7, std= 97.9, range=[1084, 1322]
#
# n=50:
#   κ=   1: mean=   2.0, std=  0.0, range=[  2,   2]
#   κ=   2: mean=  21.7, std=  0.5, range=[ 21,  22]
#   κ=   5: mean=  35.7, std=  2.6, range=[ 32,  38]
#   κ=  10: mean=  70.0, std=  4.3, range=[ 64,  74]
#   κ=  20: mean= 118.3, std= 19.8, range=[101, 146]
#   κ=  50: mean= 263.7, std=  6.9, range=[255, 272]
#   κ= 100: mean= 594.3, std= 31.0, range=[557, 633]
#   κ= 200: mean=1115.0, std= 30.5, range=[1090, 1158]
#
# n=100:
#   κ=   1: mean=   2.0, std=  0.0, range=[  2,   2]
#   κ=   2: mean=  21.0, std=  0.0, range=[ 21,  21]
#   κ=   5: mean=  38.0, std=  1.6, range=[ 36,  40]
#   κ=  10: mean=  74.3, std=  3.7, range=[ 70,  79]
#   κ=  20: mean= 102.7, std= 15.2, range=[ 82, 118]
#   κ=  50: mean= 268.3, std= 42.0, range=[209, 299]
#   κ= 100: mean= 539.7, std= 95.0, range=[406, 618]
#   κ= 200: mean=1210.7, std= 43.8, range=[1153, 1259]

# %% [markdown]
# Число итераций сильно растет с увеличением κ
#
# При κ=1: ~10-50 итераций
#
# При κ=100: ~200-500 итераций
#
# При κ=1000: ~1000-5000 итераций
#
# Вывод: Плохая обусловленность (большое κ) - основная причина медленной сходимости
#
# ---------------------------------------------------------
# Кривые для разных n почти совпадают
#
# Задачи размерности 10, 50, 100, 500 сходятся за схожее число итераций
#
# Вывод: Высокая размерность сама по себе не замедляет градиентный спуск
#
# -----------------------------------------------------------
